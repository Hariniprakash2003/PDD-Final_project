# %%
# %run trainer.py
# Out:
# Epoch 1: Train Loss=0.7230, Train F1=0.469
# Epoch 2: Train Loss=0.6123, Train F1=0.720
# Epoch 3: Train Loss=0.5402, Train F1=0.748
# Epoch 4: Train Loss=0.4260, Train F1=0.833
# Epoch 5: Train Loss=0.4249, Train F1=0.791
# Epoch 6: Train Loss=0.3114, Train F1=0.861
# Epoch 7: Train Loss=0.3189, Train F1=0.861
# Epoch 8: Train Loss=0.3724, Train F1=0.805
# Epoch 9: Train Loss=0.2035, Train F1=0.931
# Epoch 10: Train Loss=0.2802, Train F1=0.875
# Epoch 11: Train Loss=0.1736, Train F1=0.931
# Epoch 12: Train Loss=0.2069, Train F1=0.931
# Epoch 13: Train Loss=0.1690, Train F1=0.958
# Epoch 14: Train Loss=0.1777, Train F1=0.931
# Epoch 15: Train Loss=0.1196, Train F1=0.958
# Epoch 16: Train Loss=0.1578, Train F1=0.944
# Epoch 17: Train Loss=0.2068, Train F1=0.903
# Epoch 18: Train Loss=0.0591, Train F1=1.000
# Epoch 19: Train Loss=0.1428, Train F1=0.958
# Epoch 20: Train Loss=0.0724, Train F1=0.986
# Epoch 21: Train Loss=0.0557, Train F1=1.000
# ...
